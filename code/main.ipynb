# %%
# Imports 

# Pandas: Data manipulation and analysis
import pandas as pd

# NumPy: Scientific computing with arrays, array manipulation
import numpy as np

# Matplotlib: Plotting library
import matplotlib.pyplot as plt

# sys: Access system-specific parameters and functions
import sys

# os: Interact with the operating system
import os

# importlib: Dynamic module import
import importlib

# contextlib: Utilities for working with context managers
from contextlib import contextmanager

# %%
# Context manager to temporarily add a directory to sys.path
# This ensures the directory is added to sys.path when entering the context
# and removed from sys.path when exiting the context
@contextmanager
def add_sys_path(path):
    """
    Temporarily adds the specified path to sys.path.

    Parameters:
    path (str): The directory path to add to sys.path.

    Yields:
    None
    """
    # Check if the specified path is already in sys.path
    if path not in sys.path:
        # If not, append the path to sys.path
        sys.path.append(path)
    try:
        # Yield control back to the calling context
        # Code within the 'with' block will execute at this point
        yield
    finally:
        # This block will always execute upon exiting the context
        # Check if the path is in sys.path
        if path in sys.path:
            # If it is, remove the path from sys.path
            sys.path.remove(path)

# Function to import and reload modules if necessary
def import_and_reload(module_name, path):
    """
    Imports and reloads the specified module from the given path.

    Parameters:
    module_name (str): The name of the module to import and reload.
    path (str): The directory path where the module is located.

    Returns:
    module: The imported and reloaded module.
    """
    # Use the add_sys_path context manager to temporarily add the path to sys.path
    with add_sys_path(path):
        # Import the module using its name
        module = importlib.import_module(module_name)
        # Reload the module to ensure any changes are reflected
        importlib.reload(module)
        # Return the imported and reloaded module
        return module

# %%
# Setting working directory

# Define the path to the working directory
working_directory = '/Users/ruzejjur/Github/TMoCOBoT_python'

# Change the current working directory to the specified path
os.chdir(working_directory)

# %%
# Add and import auxiliary script
auxiliary_path = os.path.abspath(os.path.join(working_directory, 'code', 'auxiliary'))
auxiliary = import_and_reload('auxiliary', auxiliary_path)

# Add and import testing script
testing_path = os.path.abspath(os.path.join(working_directory, 'code', 'auxiliary'))
testing = import_and_reload('testing', testing_path)

# Add and import testing script
helper_path = os.path.abspath(os.path.join(working_directory, 'code', 'auxiliary'))
helper_functions = import_and_reload('helper_functions', testing_path)

# %% [markdown]
# # Simulated examples
#
# To simplify the analysis, specific parameters are defined for the experts, which include the following:
#
#  - 10 experts for each brand.
#  - 3 mobile brands.
#  - 3 features.
#  - 6 score values.
#
# These parameters have been deliberately chosen to configure the system and demonstrate the functionality of our proposed solution.
#
# The parameters associated with the modeller are as follows:
#
#  - The preference score $r_{I,n}$ = 4 for all features.
#  - The modeller's brand $P_{I}(B)$ preference follows a uniform distribution.
#  - The modeller's opinion on brands $b\in{B}$ is established in the experimental setup.
#  - The modeller's certainty $c_{I,b,n} \in \langle 0, 1 \rangle$ is established in the experimental setup.
#  - The modeller's trust $t_{I,E_{i}} \in \langle 0, 1 \rangle$ is established in the experimental setup.
#
# The preference score is set for simplicity, eliminating one hyperparameter to tune.
# The modeller's brand preference $P_{I}(B)$ is configured to ensure that the choice of the brand $b\in{B}$ is not influenced by the modeller's bias.
#
# The objective is to design experiments in such a way that the brand selection process can be inferred from the setup of the experts.
#
# In the following five examples, the modeller's opinions are presented in the following table:

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [5, 4, 5],  # Scores for Brand_1
    [6, 5, 6],  # Scores for Brand_2
    [4, 4, 3]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],  # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %% [markdown]
# The modeller's opinion on brands is as follows: **Brand_2 > Brand_1 > Brand_3**.

# %% [markdown]
# ## Opinion Merging and Preference Sub-setting
#
# The aim of this section is to illustrate the influence of expert opinions on the modeller's brand preference.

# %% [markdown]
# ### Example 1
# The experts are configured to prefer the brands in the following order:
#
#  **Brand_1 > Brand_2 > Brand_3**.
#
# The Brand_1 is slightly more preferred than Brand_2, this is set up for later demonstration of the trust value $t_{I,E_{i}}$ in 'Inclusion of trust' section.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# Converting the modeller's scores to a DataFrame for better readability

# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],  # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Printing the DataFrame
print("The modeller's Scores:")
primary_modeller_scores_df
# Out:
# The modeller's Scores:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
# ! Note 1: ones does not equate to no certainty being applied as the opinion certainty is multiplied with number of responders
opinion_certainty_array = np.array([1, 1, 1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = False

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10),dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.int8)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# #### Expert opinions

# %% [markdown]
# The opinion's of individual experts $E_{i}$ for each brand $b\in{B}$.

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [4, 3, 4], [5, 3, 5], [5, 6, 5], [6, 5, 3], [6, 6, 6], 
    [5, 6, 5], [6, 6, 5], [6, 3, 4], [4, 5, 4], [6, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %%
print("Brand_1 Experts' Opinions:")
Brand_1_expert_opinions_df
# Out:
# Brand_1 Experts' Opinions:
#                    Feature 1 score  Feature 2 score  Feature 3 score
# Brand_1 expert 1                 4                3                4
# Brand_1 expert 2                 5                3                5
# Brand_1 expert 3                 5                6                5
# Brand_1 expert 4                 6                5                3
# Brand_1 expert 5                 6                6                6
# Brand_1 expert 6                 5                6                5
# Brand_1 expert 7                 6                6                5
# Brand_1 expert 8                 6                3                4
# Brand_1 expert 9                 4                5                4
# Brand_1 expert 10                6                4                3

# %%
print("\nBrand_2 Experts' Opinions:")
Brand_2_expert_opinions_df
# Out:
# Brand_2 Experts' Opinions:
#                    Feature 1 score  Feature 2 score  Feature 3 score
# Brand_2 expert 1                 5                5                5
# Brand_2 expert 2                 5                6                5
# Brand_2 expert 3                 3                4                4
# Brand_2 expert 4                 3                4                5
# Brand_2 expert 5                 4                5                5
# Brand_2 expert 6                 5                6                4
# Brand_2 expert 7                 6                6                6
# Brand_2 expert 8                 5                6                6
# Brand_2 expert 9                 4                3                4
# Brand_2 expert 10                4                6                3

# %%
print("\nBrand_3 Experts' Opinions:")
Brand_3_expert_opinions_df
# Out:
# Brand_3 Experts' Opinions:
#                    Feature 1 score  Feature 2 score  Feature 3 score
# Brand_3 expert 1                 3                4                3
# Brand_3 expert 2                 3                3                4
# Brand_3 expert 3                 4                3                4
# Brand_3 expert 4                 3                3                3
# Brand_3 expert 5                 5                4                3
# Brand_3 expert 6                 3                5                5
# Brand_3 expert 7                 4                5                6
# Brand_3 expert 8                 4                3                2
# Brand_3 expert 9                 3                4                3
# Brand_3 expert 10                4                3                4

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate simple mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/2855660993.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %% [markdown]
# <ins>The modeller's brand preference after opinion merging.</ins>

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_0.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  41.6459%  33.3333%  25.0208%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  41.6667%  33.3333%  25.0000%

# %%
exp_1_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD and linear pooling difference:"

df = helper_functions.format_and_display_percentages(
    exp_1_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference FPD and linear pooling difference:
#        Brand 1      Brand 2      Brand 3
# 0  0.02078062%  0.00000277%  0.02077785%

# %% [markdown]
# The results suggest that the experts influenced the modeller's opinion to favour the Brand_1 brand. Additionally, the modeller's probability of choosing the Brand_3 brand prior to opinion merging is low due to the low score assigned to feature 3 for the Brand_3 brand.  Consequently, this leads to a low probability entering the posterior distribution before opinion merging, significantly reducing the probability of selecting the Brand_3 brand.

# %% [markdown]
# ### Example 2

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],           # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
# ! Note 1: ones does not equate to no certainty being applied as the opinion certainty is multiplied with number of responders
opinion_certainty_array = np.array([1, 1, 1], dtype = np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = False

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype = np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10), dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float16)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# ##### Expert opinons

# %% [markdown]
# The experts are configured to prefer the brands in the following order:
#
#  **Brand_1 $\approx$ Brand_2 $\approx$ Brand_3**,
#
# the scores are set up to similar **<ins>high</ins>** values.

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [6, 5, 6], [5, 5, 5], [6, 5, 5], [5, 5, 6], [6, 6, 6],
    [5, 6, 5], [6, 5, 5], [6, 5, 5], [5, 6, 6], [6, 5, 5]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 6, 5], [6, 5, 5], [6, 5, 6], [5, 6, 5], [6, 6, 5],
    [6, 5, 6], [6, 6, 6], [6, 5, 6], [5, 6, 5], [6, 6, 6]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [5, 5, 6], [6, 5, 6], [6, 6, 6], [6, 6, 6], [6, 5, 6],
    [6, 5, 5], [6, 5, 6], [5, 5, 6], [6, 6, 5], [5, 6, 5]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format
# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/3988871084.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_1.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  33.5610%  32.8780%  33.5610%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  33.5616%  32.8767%  33.5616%

# %%
exp_2_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD and linear pooling difference:"

df = helper_functions.format_and_display_percentages(
    exp_2_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference FPD and linear pooling difference:
#        Brand 1      Brand 2      Brand 3
# 0  0.00065267%  0.00130832%  0.00065267%

# %% [markdown]
# Comment on this result are at the end of this section.

# %% [markdown]
# ### Example 3

# %% [markdown]
# The experts are configured to prefer the brands in the following order:
#
# **Brand_1 $\approx$ Brand_2 $\approx$ Brand_3**,
#
# the scores are set up to similar **<ins>low</ins>** values.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],           # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
# ! Note 1: ones does not equate to no certainty being applied as the opinion certainty is multiplied with number of responders
opinion_certainty_array = np.array([1, 1, 1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = False

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10), dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float32)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# #### Expert opinions

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [3, 4, 4], [3, 4, 4], [4, 4, 4], [4, 3, 3], [4, 3, 3],
    [4, 4, 1], [4, 1, 4], [4, 3, 4], [4, 5, 4], [4, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [4, 4, 4], [4, 3, 4], [4, 4, 4], [4, 4, 2], [4, 3, 4],
    [3, 4, 1], [4, 4, 4], [2, 4, 4], [1, 4, 4], [3, 2, 1]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [4, 4, 4], [4, 4, 4], [3, 5, 4], [4, 4, 4], [2, 1, 4],
    [4, 4, 5], [3, 4, 2], [4, 3, 4], [4, 4, 1], [1, 2, 3]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_2.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  32.8780%  33.5610%  33.5610%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  32.8767%  33.5616%  33.5616%

# %%
exp_3_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD and linear pooling difference:"

df = helper_functions.format_and_display_percentages(
    exp_3_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference FPD and linear pooling difference:
#        Brand 1      Brand 2      Brand 3
# 0  0.00130832%  0.00065565%  0.00065565%

# %% [markdown]
# The results of the last two experiments show only a minor difference in the final brand preference. However, it was expected that the modeller's opinion would have a stronger influence, pushing the preference towards the following order: **Brand_2 > Brand_1 > Brand_3**.
#
# This is attributed to the fact that each expert's contribution to the updated weight $V_{f_{j,b}}$ has a magnitude of +1, and the modeller's contribution is also + 1. The cumulative effect of the experts' contributions diminishes the impact of the modeller's opinion.
#
# To address this, the magnitude of the modeller's weights $n_{f_{1,b}}$ needs to be adjusted to ensure that the modeller's opinion is not diminished. Further elaboration on this adjustment will be provided in the section titled 'Inclusion of Opinion Certainty' below.

# %% [markdown]
# ## Inclusion of trust
# In this section, we are examining the integration of trust $t_{I,E_{i}}$, into each expert's $E_{i}$ opinion.  The previously mentioned issue still exists and will be addressed later.
# For now, the modeller's opinion will be de-emphasized. This approach allows for a more precise demonstration of trust inclusion, free from any bias introduced by the modeller's opinion.
# For simplicity, the setup of the following two experiments is the same as in the first example from the previous section.

# %% [markdown]
# ### Example 1
# We start by configuring low trust values $t_{I,E_{i}}$ for experts reacting to the Brand_1 brand and high trust values for experts reacting to Brand_2 and Brand_3. The expected outcome is that the preferred brand should be Brand_2, since it has similar score values provided by the experts' $E_{i}$ as Brand_1, with Brand_2 being slightly less favoured.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [5, 4, 5],  # Scores for Brand_1
    [6, 5, 6],  # Scores for Brand_2
    [4, 4, 3]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],           # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
# ! Note 1: ones does not equate to no certainty being applied as the opinion certainty is multiplied with number of responders
opinion_certainty_array = np.array([1, 1, 1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = False

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Setting up trust in experts' opinions

# Trust matrix representing the trust levels for each expert's opinion
# Rows represent phone brands (Brand_1, Brand_2, Brand_3)
# Columns represent individual experts' trust levels
trust_matrix = np.array([
    [0.8, 0.9, 0.3, 0.7, 0.2, 0.2, 0.3, 0.5, 0.4, 0.9],  # Trust levels for Brand_1 experts
    [0.9, 0.9, 0.3, 0.3, 0.7, 0.7, 0.9, 0.9, 0.4, 0.4],  # Trust levels for Brand_2 experts
    [0.9, 0.7, 0.8, 0.8, 0.9, 0.8, 0.7, 0.7, 0.8, 0.9]   # Trust levels for Brand_3 experts
], dtype=np.float32)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float32)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# #### Expert opinions

# %% [markdown]
# The opinion's of individual experts $E_{i}$ for each brand $b\in{B}$.

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [4, 3, 4], [5, 3, 5], [5, 6, 5], [6, 5, 3], [6, 6, 6], 
    [5, 6, 5], [6, 6, 5], [6, 3, 4], [4, 5, 4], [6, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_3.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  28.8194%  46.0186%  25.1620%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  28.8729%  46.0576%  25.0695%

# %%
exp_4_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    exp_4_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#        Brand 1      Brand 2      Brand 3
# 0  0.05358756%  0.03895164%  0.09253025%

# %% [markdown]
# ### Example 2
# Setting the trust $t_{I,E_{i}}$ for experts reacting to Brand_1 and Brand_2 brands to low values and to high values for Brand_3. The preferred brand should be Brand_3.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [5, 4, 5],  # Scores for Brand_1
    [6, 5, 6],  # Scores for Brand_2
    [4, 4, 3]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],  # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          5          4          5
# Brand 2          6          5          6
# Brand 3          4          4          3

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
# ! Note 1: ones does not equate to no certainty being applied as the opinion certainty is multiplied with number of responders
opinion_certainty_array = np.array([1, 1, 1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = False

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Setting up trust in experts' opinions

# Trust matrix representing the trust levels for each expert's opinion
# Rows represent phone brands (Brand_1, Brand_2, Brand_3)
# Columns represent individual experts' trust levels
trust_matrix = np.array([
    [0.8, 0.9, 0.5, 0.9, 0.2, 0.2, 0.2, 0.5, 0.4, 0.9],  # Trust levels for Brand_1 experts
    [0.3, 0.3, 0.9, 0.9, 0.5, 0.5, 0.2, 0.2, 0.8, 0.8],  # Trust levels for Brand_2 experts
    [0.5, 0.7, 0.9, 0.2, 0.9, 0.8, 0.9, 0.7, 0.8, 0.9]   # Trust levels for Brand_3 experts
], dtype=np.float32)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float32)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# ##### Expert opinions

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [4, 3, 4], [5, 3, 5], [5, 6, 5], [6, 5, 3], [6, 6, 6], 
    [5, 6, 5], [6, 6, 5], [6, 3, 4], [4, 5, 4], [6, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_4.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)

df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  35.0247%  23.6347%  41.3405%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  35.0767%  23.6383%  41.2850%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  35.0767%  23.6383%  41.2850%

# %%
exp_5_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    exp_5_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#        Brand 1      Brand 2      Brand 3
# 0  0.05199611%  0.00354201%  0.05553961%

# %% [markdown]
# The trust process works as intended.

# %% [markdown]
# ### Inclusion of certainty
# This section aims to provide a solution to the problem of setting the modeller's initial weights $n_{f_{1,b}}$ so that the modeller's opinion is not diminished, this is described in the first three examples.
# To better demonstrate the proposed solution, the trust values $t_{I,E_{i}} \in \langle 0, 1 \rangle$ are intentionally excluded. When the trust value is not set, it is equivalent to setting the trust $t_{I,E_{i}}$ to the maximum value of 1.
# In contrast, in the opposite scenario, the weight increments of the experts are generally $t_{I,E_{i}} \in \langle 0, 1 \rangle$, this effect is linearly combined with the value of opinion certainty $c_{I,b,n}$.
# A simplified solution was deemed to be sufficient.
#
# For simplicity, the setup of the following three examples are the same as in the first example from the first section, apart from the setup of the modeller's opinion and opinion certainty.

# %% [markdown]
# ### Example 1:
# This example illustrates the impact of the opinion certainty $c_{I,b,n}$ on the final brand ordering. Setting maximum opinion certainty $c_{I,b,n}$ = 1 in the modeller's low scores for the Brand_1 brand should lead to the preference for the Brand_2 as the top brand, Brand_3 being the second most preferred brand.
#
# The modeller's opinion is configured to prefer the brands in the following order:
#
# **Brand_2 > Brand_3 > Brand_1**.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [3, 4, 1],  # Scores for Brand_1
    [6, 5, 6],  # Scores for Brand_2
    [4, 4, 3]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Create a DataFrame
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],
    columns=["Feature 1", "Feature 2", "Feature 3"]
)

# Display the DataFrame
print("The modellers Scores Table:")
primary_modeller_scores_df
# Out:
# The modellers Scores Table:
#          Feature 1  Feature 2  Feature 3
# Brand 1          3          4          1
# Brand 2          6          5          6
# Brand 3          4          4          3

# %% [markdown]
# The modeller's certainty in the opinion $c_{I,b,n}$ for each brand is the following:

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
opinion_certainty_array = np.array([1, 0.4, 0.1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = True

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "Opinion Certainty Table:"

df = helper_functions.format_and_display_percentages(
    opinion_certainty_array,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# Opinion Certainty Table:
#      Brand 1   Brand 2   Brand 3
# 0  100.0000%  40.0000%  10.0000%

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10), dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float32)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# ##### Expert opinions

# %% [markdown]
# Low values of opinion certainty $c_{I,b,n}$ for Brand_2 and Brand_3, result in higher influence of the experts' opinion on the opinion of the modeller. This can be intuitively interpreted as the modeller being more receptive to advice from the experts $E_{i}$.

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [4, 3, 4], [5, 3, 5], [5, 6, 5], [6, 5, 3], [6, 6, 6], 
    [5, 6, 5], [6, 6, 5], [6, 3, 4], [4, 5, 4], [6, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_5.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  19.9743%  47.4450%  32.5806%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  19.9053%  47.4667%  32.6280%

# %%
exp_6_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    exp_6_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#        Brand 1      Brand 2      Brand 3
# 0  0.06902215%  0.02166641%  0.04735276%

# %% [markdown]
# The opinion certainty process works as intended in this example.

# %% [markdown]
# ### Example 2
# In this example the maximum opinion certainty $c_{I,b,n}$ = 1 in the modeller's low scores for the Brand_1 and Brand_2 brand should lead to the preference for the Brand_3 brand.
#
# The modeller's opinion is configured to prefer the brands in the following order:
#
# **Brand_3 > Brand_2 > Brand_1**.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [3, 1, 1],  # Scores for Brand_1
    [2, 3, 1],  # Scores for Brand_2
    [6, 5, 5]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],           # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          3          1          1
# Brand 2          2          3          1
# Brand 3          6          5          5

# %% [markdown]
# The modeller's certainty in the opinion $c_{I,b,n}$ for each brand is the following:

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
opinion_certainty_array = np.array([0.2, 0.2, 1], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = True

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "Opinion Certainty Table:"

df = helper_functions.format_and_display_percentages(
    opinion_certainty_array,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# Opinion Certainty Table:
#     Brand 1   Brand 2    Brand 3
# 0  20.0000%  20.0000%  100.0000%

# %% [markdown]
# Similarly to the previous example, low values of opinion certainty $c_{I,b,n}$ for Brand_1 and Brand_2, result in higher influence of the experts' opinion on the opinion of the modeller. This can be intuitively interpreted as the modeller being more receptive to advice from the experts $E_{i}$.

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10), dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float32)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# ##### Expert opinions

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [4, 3, 4], [5, 3, 5], [5, 6, 5], [6, 5, 3], [6, 6, 6], 
    [5, 6, 5], [6, 6, 5], [6, 3, 4], [4, 5, 4], [6, 4, 3]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_6.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  17.9542%  17.9542%  64.0916%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  17.9741%  17.9741%  64.0518%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  17.9741%  17.9741%  64.0518%

# %%
exp_7_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    exp_7_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#        Brand 1      Brand 2      Brand 3
# 0  0.01986403%  0.01986403%  0.03973105%

# %% [markdown]
# The opinion certainty process works as intended in this example.

# %% [markdown]
# ### Example 3
# In this example the maximum opinion certainty $c_{I,b,n}$ = 1 in the modeller's lowest scores for Brand_1 brand should lead to the preference for the Brand_2 brand.
#
# The modeller's opinion is configured to prefer the brands in the following order:
#
# **Brand_2 > Brand_3 > Brand_1**.

# %% [markdown]
# #### Experiment setup

# %% [markdown]
# ##### Agent

# %%
# The modeller's opinion

# Array representing the scores given by the modeller for different phone brands and features
# * Note 1: This array represents modellers opinion
primary_modeller_scores = np.array([
    [1, 1, 1],  # Scores for Brand_1
    [6, 5, 6],  # Scores for Brand_2
    [4, 4, 3]   # Scores for Brand_3
], dtype=np.int8)

# %%
# Creating a DataFrame with the given data
# Index represents phone brands, and columns represent different features
primary_modeller_scores_df = pd.DataFrame(
    primary_modeller_scores,
    index=["Brand 1", "Brand 2", "Brand 3"],           # Setting the row labels for phone brands
    columns=["Feature 1", "Feature 2", "Feature 3"]  # Setting the column labels for features
)

# Display the DataFrame
primary_modeller_scores_df
# Out:
#          Feature 1  Feature 2  Feature 3
# Brand 1          1          1          1
# Brand 2          6          5          6
# Brand 3          4          4          3

# %% [markdown]
# Additionally, to simulate an issue with this design, all the experts' opinions for Brand_1 are deliberately set to the highest scores.
#
# The modeller's certainty in the opinion $c_{I,b,n}$ for each brand is the following:

# %%
# Setting up the opinion certainty

# Array representing the certainty of the modeller's opinion for each phone brand
opinion_certainty_array = np.array([1, 0, 0], dtype=np.float16)

# Boolean flag to determine if certainty should be applied
# * Note 1: This flag is important as setting it to True will ensure that the opinion certainty array is ones.
apply_certainty = True

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "Opinion Certainty Table:"

df = helper_functions.format_and_display_percentages(
    opinion_certainty_array,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# Opinion Certainty Table:
#      Brand 1  Brand 2  Brand 3
# 0  100.0000%  0.0000%  0.0000%

# %%
# Setting up the number of responders for each brand so that the opinion
# certainty can be applied as many times as the responders responded

# Array representing the number of responders for each phone brand
number_of_responders = np.array([10, 10, 10], dtype=np.int32)

# %%
# Create a trust matrix with ones, representing equal trust for each responder
# The matrix has 3 rows (one for each phone brand) and 10 columns (one for each responder)
# * Note 1: Setting trust like this is equivalent to no inclusion of trust
trust_matrix = np.ones((3, 10), dtype=np.float16)

# %%
# modeller's score preference for each feature

# Array representing the modeller's score preference for each feature
# * Note 1: This means that scores below the selected scores are not taken into acoount durring the opinion formulation
primary_modeller_score_preference = np.array([4, 4, 4], dtype=np.int8)

# %%
# modeller's brand preference

# Array representing the modeller's initial brand preference
# * Note 1: Set to uniform
primary_modeller_brand_pref = np.array([1, 1, 1], dtype=np.float16)

# Normalize the brand preference so that the sum equals 1
primary_modeller_brand_pref = primary_modeller_brand_pref / np.sum(primary_modeller_brand_pref)

# %%
# Setting score range

# This represents the highest possible score for each feature, i.e., score range = 'best'
score_range = 6

# %%
# The values of exponents in Dirichlet distribution must be non-zero,
# setting them to a low value

# Initial feature weight for the Dirichlet distribution
initial_feature_weight = 0.01

# %% [markdown]
# When opinion certainty values $c_{I,b,n}$ for Brand_2 and Brand_3 are set to zero, it results in the complete influence of the experts' opinions on the modeller's own opinion. This can be intuitively interpreted as the modeller completely replacing his own opinion with the opinions of the experts $E_{i}$.

# %% [markdown]
# ##### Expert opinions

# %%
# Simulated experts for Brand_1
# Array representing the opinions of 10 simulated experts on Brand_1 for 3 features
Brand_1_expert_opinions = np.array([
    [6, 6, 6], [6, 6, 6], [6, 6, 6], [6, 6, 6], [6, 6, 6], 
    [6, 6, 6], [6, 6, 6], [6, 6, 6], [6, 6, 6], [6, 6, 6]
], dtype=np.int8)

# Simulated experts for Brand_2
# Array representing the opinions of 10 simulated experts on Brand_2 for 3 features
Brand_2_expert_opinions = np.array([
    [5, 5, 5], [5, 6, 5], [3, 4, 4], [3, 4, 5], [4, 5, 5], 
    [5, 6, 4], [6, 6, 6], [5, 6, 6], [4, 3, 4], [4, 6, 3]
], dtype=np.int8)

# Simulated experts for Brand_3
# Array representing the opinions of 10 simulated experts on Brand_3 for 3 features
Brand_3_expert_opinions = np.array([
    [3, 4, 3], [3, 3, 4], [4, 3, 4], [3, 3, 3], [5, 4, 3], 
    [3, 5, 5], [4, 5, 6], [4, 3, 2], [3, 4, 3], [4, 3, 4]
], dtype=np.int8)

# %%
# Creating DataFrames for each brand

# DataFrame for Brand_1 expert opinions
Brand_1_expert_opinions_df = pd.DataFrame(
    Brand_1_expert_opinions, 
    index=[f"Brand_1 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_2 expert opinions
Brand_2_expert_opinions_df = pd.DataFrame(
    Brand_2_expert_opinions,
    index=[f"Brand_2 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# DataFrame for Brand_3 expert opinions
Brand_3_expert_opinions_df = pd.DataFrame(
    Brand_3_expert_opinions, 
    index=[f"Brand_3 expert {i+1}" for i in range(10)],  # Setting index as expert identifiers
    columns=["Feature 1 score", "Feature 2 score", "Feature 3 score"]  # Setting the column labels for features
)

# %% [markdown]
# <ins>Simple inference of experts opinion of brands</ins>

# %%
# Calculate the mean scores of each expert
Brand_1_means = Brand_1_expert_opinions_df.mean(axis=1)
Brand_2_means = Brand_2_expert_opinions_df.mean(axis=1)
Brand_3_means = Brand_3_expert_opinions_df.mean(axis=1)

# Create a box plot for each brand
fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)
ax.set_title('Box Plot of Mean Expert Scores for Each Brand', fontsize=15.5)
ax.set_ylabel('Mean Score')
ax.set_xlabel('Brand')

# Adding scatter plot of the observations
x_positions = [1, 2, 3]
for i, means in enumerate([Brand_1_means, Brand_2_means, Brand_3_means]):
    ax.scatter([x_positions[i]] * len(means), means, alpha=0.6, color='blue', s=5)

# Save the figure in .eps format

# save_path = os.path.join(working_directory, 'Bar_charts', 'brand_mean_scores_boxplot.eps')
# plt.tight_layout()
# plt.savefig(save_path, format='eps')

# Show the plot
plt.show()
# Out:
# /var/folders/wm/cf004srn2bx_p8lzdm9k_rr80000gn/T/ipykernel_96382/841215693.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([Brand_1_means, Brand_2_means, Brand_3_means], labels=["Brand 1", "Brand 2", "Brand 3"], showmeans=True)

# %%
# Running the simulated example from the auxiliary module

# Call the simulated_example function with the provided parameters
primary_modeler_posterior_updated_lin_pool, primary_modeller_posterior_updated_FPD = auxiliary.simulated_example(
    primary_modeller_scores,  # Initial scores given by the modeller
    opinion_certainty_array,  # Certainty of the modeller's opinions
    apply_certainty,  # Flag to apply certainty
    number_of_responders,  # Number of responders for each brand
    trust_matrix,  # Trust matrix representing trust for each responder
    primary_modeller_score_preference,  # modeller's score preference for each feature
    primary_modeller_brand_pref,  # Distribution representing modeller's brand prefference
    score_range,  # Highest possible score for each feature
    initial_feature_weight,  # Initial feature weight for the Dirichlet distribution
    Brand_1_expert_opinions,  # Expert opinions for Brand_1
    Brand_2_expert_opinions,  # Expert opinions for Brand_2
    Brand_3_expert_opinions  # Expert opinions for Brand_3
)

# %%
## Plot modeller's updated posterior distribution on brands

variable_names = ['Brand 1', 'Brand 2', 'Brand 3']
save_file_path = os.path.join(working_directory, 'Bar_charts', 'figure_7.eps')

helper_functions.plot_posterior_distribution(
    variable_names=variable_names,
    data=primary_modeller_posterior_updated_FPD,
    y_label='Probability',
    title="Modeller's Updated Brand Preference",
    save_path=save_file_path
)

# %% [markdown]
# <ins>The modeller's updated brand preference.</ins>

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD:"

df = helper_functions.format_and_display_percentages(
    primary_modeller_posterior_updated_FPD,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference FPD:
#     Brand 1   Brand 2   Brand 3
# 0  51.9744%  33.0989%  14.9267%

# %%
# Round the values and convert them to percentage strings

column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference linear pooling:"

df = helper_functions.format_and_display_percentages(
    primary_modeler_posterior_updated_lin_pool,
    column_names,
    header,
    decimal_places=4
)
df
# Out:
# The modeller's updated brand preference linear pooling:
#     Brand 1   Brand 2   Brand 3
# 0  51.8672%  33.1950%  14.9378%

# %%
exp_8_brand_preference_dif = np.abs(primary_modeller_posterior_updated_FPD - primary_modeler_posterior_updated_lin_pool)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD and linear pooling difference:"

df = helper_functions.format_and_display_percentages(
    exp_8_brand_preference_dif,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference FPD and linear pooling difference:
#        Brand 1      Brand 2      Brand 3
# 0  0.10722566%  0.09616513%  0.01105755%

# %% [markdown]
# In this scenario, an unexpected outcome occurs due to the way each expert's $E_{i}$ contribution to the updated weight $V_{f_{j,b}}$ and the modeller's contribution are configured. In particular:
#
#  1. Each expert's contribution to the updated weight $V_{f_{i,b}}$ has a magnitude of +1.
#  2. The modeller's contribution to the updated weight $V_{f_{i,b}}$ is also +1 for each expert, given that opinion certainty $c_{I,b,n}$ is set to the maximum value of 1.
#
# As a result, the updated weight becomes $V_{i_{Brand_1}}$ = 10 for all $i\in \{1,2,3\}$. This leads to high maximum values for the respective probabilities $P_{I}^{0}(F_{i,Brand_1}|Brand_1)$ for all $i\in \{1,2,3\}$, of choosing the underlying scores. Consequently, the probabilities entering the final posterior distribution on brands $P_{I}^{0}(F_{1,Brand_1}|Brand_1)P_{I}^{0}(F_{2,Brand_1}|Brand_1)P_{I}^{0}(F_{3,Brand_1}|Brand_1)$ remain high, resulting in the selection of the Brand_1 brand, contrary to the expected outcome.

# %% [markdown]
# ## Calculating average proportional difference between FPD and linear pooling opinion merging

# %%
modeller_brand_pref_posterior_diff_mat = np.array([exp_1_brand_preference_dif,
                                                         exp_2_brand_preference_dif,
                                                         exp_3_brand_preference_dif,
                                                         exp_4_brand_preference_dif,
                                                         exp_5_brand_preference_dif,
                                                         exp_6_brand_preference_dif,
                                                         exp_7_brand_preference_dif,
                                                         exp_8_brand_preference_dif])



#brand_pref_posterior_avg_diff

# %%
modeller_brand_pref_posterior_diff_avg = np.average(modeller_brand_pref_posterior_diff_mat, axis=0)


column_names = ["Brand 1", "Brand 2", "Brand 3"]
header = "The modeller's updated brand preference FPD and linear pooling average difference for each brand:"

df = helper_functions.format_and_display_percentages(
    modeller_brand_pref_posterior_diff_avg,
    column_names,
    header,
    decimal_places=8
)
df
# Out:
# The modeller's updated brand preference FPD and linear pooling average difference for each brand:
#        Brand 1      Brand 2      Brand 3
# 0  0.04055464%  0.02276950%  0.03353717%
